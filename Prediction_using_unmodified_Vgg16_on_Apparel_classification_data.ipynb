# %% [markdown]
# <a href="https://colab.research.google.com/github/krishroop/Fashion-Classification-using-Deep-Learning/blob/main/Prediction_using_unmodified_Vgg16_on_Apparel_classification_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
image_path = "sample_data/testImage.jpg"

# %% [markdown]
# #2. Loading Image and opening it

# %%
from keras.preprocessing import image

img = image.load_img(image_path, target_size=(224, 224))

plt.imshow(img)
plt.show()

# %% [markdown]
# #3.Preprocessing the Image

# %%
from keras.applications.imagenet_utils import preprocess_input
from keras.applications.imagenet_utils import decode_predictions

testImage=image.img_to_array(img)
testImage=np.expand_dims(testImage,axis=0)
ProcessedTestImage=preprocess_input(testImage)

# %% [markdown]
# #4.Importing Vgg16 model and printing its details

# %%
from keras.applications.vgg16 import VGG16

model = VGG16()

model.summary()
# Out:
# ...
# 553467904/553467096 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %% [markdown]
# #5.Using VGG16 to predict labels for testImage

# %%
feature = model.predict(ProcessedTestImage)
plt.imshow(img)
decode_predictions(feature,10)
# Out:
# [[('n02916936', 'bulletproof_vest', 0.30574402),
#   ('n03866082', 'overskirt', 0.17426567),
#   ('n04479046', 'trench_coat', 0.17141463),
#   ('n03763968', 'military_uniform', 0.09253309),
#   ('n04325704', 'stole', 0.03360057),
#   ('n03980874', 'poncho', 0.02916627),
#   ('n04525038', 'velvet', 0.028539283),
#   ('n03534580', 'hoopskirt', 0.024546038),
#   ('n02769748', 'backpack', 0.022362193),
#   ('n03404251', 'fur_coat', 0.015713148)]]
